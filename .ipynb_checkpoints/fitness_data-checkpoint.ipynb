# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
fitness_data = "resources/fitness_trends.csv"

# %%
fitness_df = pd.read_csv(fitness_data)
fitness_df.head(50)
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  \
# 0    10/6/2017        5464   200              181               5
# 1    10/7/2017        6041   100              197               8
# 2    10/8/2017          25   100                0               5
# 3    10/9/2017        5461   100              174               4
# 4   10/10/2017        6915   200              223               5
# 5   10/11/2017        4545   100              149               6
# 6   10/12/2017        4340   100              140               6
# 7   10/13/2017        1230   100               38               7
# 8   10/14/2017          61   100                1               5
# 9   10/15/2017        1258   100               40               6
# 10  10/16/2017        3148   100              101               8
# 11  10/17/2017        4687   100              152               5
# 12  10/18/2017        4732   300              150               6
# ...

# %%
#get rid of mood column
#get rid of step_count
fitness_df.drop(['mood'], axis = 1, inplace = True)
fitness_df
# Out:
#           date  step_count  calories_burned  hours_of_sleep  bool_of_active  \
# 0    10/6/2017        5464              181               5               0
# 1    10/7/2017        6041              197               8               0
# 2    10/8/2017          25                0               5               0
# 3    10/9/2017        5461              174               4               0
# 4   10/10/2017        6915              223               5             500
# ..         ...         ...              ...             ...             ...
# 91    1/5/2018         133                4               2               0
# 92    1/6/2018         153                0               8               0
# 93    1/7/2018         500                0               5             500
# 94    1/8/2018        2127                0               5               0
# 95    1/9/2018        2203                0               5             500
#
#     weight_kg
# 0          66
# 1          66
# ...

# %%
fitness_file = fitness_df.sort_values('hours_of_sleep')
fitness_file.head(50)

#change levelof activity name
# Out:
#           date  step_count  calories_burned  hours_of_sleep  bool_of_active  \
# 91    1/5/2018         133                4               2               0
# 33   11/8/2017        4068              131               2               0
# 89    1/3/2018        2599               84               2               0
# 80  12/25/2017         518               16               3               0
# 65  12/10/2017        1648               53               3             500
# 70  12/15/2017         437               14               3             500
# 64   12/9/2017        2909               93               3             500
# 86  12/31/2017          36                1               3               0
# 88    1/2/2018        1447               47               3               0
# 90    1/4/2018         702               23               3               0
# 32   11/7/2017        6041              197               3               0
# ...

# %%
#saving df into csv file 
fitness_df.to_csv('fitness.csv', index=False)
