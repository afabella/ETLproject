# %%
import pandas as pd 
import numpy as np 
import seaborn as sns

# %%
fitness_data = "resources/fitness_trends.csv"

# %%
fitness_df = pd.read_csv(fitness_data)
fitness_df.head(50)
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  \
# 0    10/6/2017        5464   200              181               5
# 1    10/7/2017        6041   100              197               8
# 2    10/8/2017          25   100                0               5
# 3    10/9/2017        5461   100              174               4
# 4   10/10/2017        6915   200              223               5
# 5   10/11/2017        4545   100              149               6
# 6   10/12/2017        4340   100              140               6
# 7   10/13/2017        1230   100               38               7
# 8   10/14/2017          61   100                1               5
# 9   10/15/2017        1258   100               40               6
# 10  10/16/2017        3148   100              101               8
# 11  10/17/2017        4687   100              152               5
# 12  10/18/2017        4732   300              150               6
# ...

# %%
#remove bool_of_active column 
fitness_df.drop(['bool_of_active'], axis = 1, inplace = True)

# %%
#remove weight_kg column 
fitness_df.drop(['weight_kg'], axis = 1, inplace = True)

# %%
#remove calories_burned column
fitness_df.drop([''])

# %%
fitness_df
# Out:
#           date  step_count  mood  calories_burned  hours_of_sleep  weight_lb
# 0    10/6/2017        5464   200              181               5     145.51
# 1    10/7/2017        6041   100              197               8     145.51
# 2    10/8/2017          25   100                0               5     145.51
# 3    10/9/2017        5461   100              174               4     145.51
# 4   10/10/2017        6915   200              223               5     145.51
# ..         ...         ...   ...              ...             ...        ...
# 91    1/5/2018         133   100                4               2     141.10
# 92    1/6/2018         153   300                0               8     141.10
# 93    1/7/2018         500   200                0               5     141.10
# 94    1/8/2018        2127   200                0               5     141.10
# 95    1/9/2018        2203   300                0               5     141.10
#
# [96 rows x 6 columns]

# %%
#saving dataframe into csv file 
fitness_df.to_csv('f.csv', index=False)
